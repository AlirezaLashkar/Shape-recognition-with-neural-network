# %%
##import Library
import numpy as np
import tensorflow as tf
from tensorflow import keras as keras
import matplotlib.pylab as plt
from tensorflow.keras.preprocessing.image  import  load_img, ImageDataGenerator
from PIL import Image

# %%
##Check the GPU
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 4152803910706383574
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 1733715559
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 12970412238122737959
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3050 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6"
# xla_global_id: 416903419
# ]

# %%
##Check the GPU
if tf.config.experimental.list_physical_devices('GPU'):
    print("Using GPU")
else:
    print("Using CPU")
# Out:
# Using GPU

# %%
##import dataset
imgSize = 100
BatchSize = 32
datagen = ImageDataGenerator(rotation_range=10,
                             height_shift_range=0.2,
                             horizontal_flip=True,
                             validation_split=0.2)
print("import image for training: ")
train_data = datagen.flow_from_directory('C:/Users/AsrNOavaran/Uni project/final neural network/multi Obj project/data set/train',
                                         target_size=(imgSize, imgSize),
                                         batch_size=BatchSize,
                                         class_mode='categorical',
                                         subset='training')
print("\nimport image for validation: ")
valid_data = datagen.flow_from_directory('C:/Users/AsrNOavaran/Uni project/final neural network/multi Obj project/data set/train',
                                         target_size=(imgSize, imgSize),
                                         batch_size=BatchSize,
                                         class_mode='categorical',
                                         subset='validation')

print("\nimport image for test: ")

test_datagen = ImageDataGenerator()

test_data = test_datagen.flow_from_directory('C:/Users/AsrNOavaran/Uni project/final neural network/multi Obj project/data set/test',
                                             target_size=(imgSize, imgSize),
                                             class_mode='categorical',
                                             batch_size=50,
                                             shuffle=False)
# Out:
# import image for training:
# Found 24320 images belonging to 19 classes.
#
# import image for validation:
# Found 6080 images belonging to 19 classes.
#
# import image for test:
# Found 7600 images belonging to 19 classes.

# %%
##show classes
print("classes: ",train_data.class_indices)
print("image_shape: " , train_data.image_shape)
# Out:
# classes:  {'class0[r]': 0, 'class10[rrc]': 1, 'class11[rrt]': 2, 'class12[rcc]': 3, 'class13[rct]': 4, 'class14[ccc]': 5, 'class15[cct]': 6, 'class16[ttt]': 7, 'class17[ttr]': 8, 'class18[ttc]': 9, 'class1[c]': 10, 'class2[t]': 11, 'class3[rr]': 12, 'class4[cc]': 13, 'class5[tt]': 14, 'class6[rc]': 15, 'class7[rt]': 16, 'class8[ct]': 17, 'class9[rrr]': 18}
# image_shape:  (100, 100, 3)

# %%
##Dictionary of classes
class_name = {
    0 : 'class0[r]', 1 : 'class10[rrc]', 
    2 : 'class11[rrt]', 3 : 'class12[rcc]',
    4 : 'class13[rct]',5: 'class14[ccc]', 
    6 : 'class15[cct]', 7 : 'class16[ttt]',
    8 : 'class17[ttr]',
    9 : 'class18[ttc]',10 : 'class1[c]',
    11 : 'class2[t]', 12 : 'class3[rr]',
    13 : 'class4[cc]', 14 : 'class5[tt]',
    15 : 'class6[rc]', 16 : 'class7[rt]',
    17 : 'class8[ct]', 18 : 'class9[rrr]'
}

# %%
##import Library
from keras.layers import Dense
from keras.layers import Input
from keras.layers import Conv2D
from keras.layers import MaxPool2D  , GlobalAveragePooling2D
from keras.layers import Flatten
from keras.models import Sequential
from tensorflow.keras.layers import Normalization

# %%
##Building a neural network model
model = Sequential()
model.add(Input((100,100,3)))
model.add(Conv2D(filters=16,kernel_size=(3,3),strides=1,activation='relu',padding='same'))
model.add(Conv2D(filters=16,kernel_size=(3,3),strides=1,activation='relu',padding='same'))
model.add(MaxPool2D())
model.add(Conv2D(filters=32,kernel_size=(3,3),strides=1,activation='relu',padding='same'))
model.add(Conv2D(filters=32,kernel_size=(3,3),strides=1,activation='relu',padding='same'))
model.add(MaxPool2D())
model.add(Conv2D(filters=64,kernel_size=(3,3),strides=1,activation='relu',padding='same'))
model.add(Conv2D(filters=64,kernel_size=(3,3),strides=1,activation='relu',padding='same'))
model.add(MaxPool2D())
model.add(Conv2D(filters=128,kernel_size=(3,3),strides=1,activation='relu',padding='same'))
model.add(Conv2D(filters=128,kernel_size=(3,3),strides=1,activation='relu',padding='same'))
model.add(MaxPool2D())
model.add(Flatten())
model.add(Dense(19,activation='softmax'))

# %%
##View the structure of the model
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 100, 100, 16)      448
#
#  conv2d_1 (Conv2D)           (None, 100, 100, 16)      2320
#
#  max_pooling2d (MaxPooling2D  (None, 50, 50, 16)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 50, 50, 32)        4640
#
#  conv2d_3 (Conv2D)           (None, 50, 50, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 25, 25, 32)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 25, 25, 64)        18496
#
#  conv2d_5 (Conv2D)           (None, 25, 25, 64)        36928
#
#  max_pooling2d_2 (MaxPooling  (None, 12, 12, 64)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 12, 12, 128)       73856
#
#  conv2d_7 (Conv2D)           (None, 12, 12, 128)       147584
#
#  max_pooling2d_3 (MaxPooling  (None, 6, 6, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 4608)              0
#
#  dense (Dense)               (None, 19)                87571
#
# =================================================================
# Total params: 381,091
# Trainable params: 381,091
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
##Introducing the necessary functions
loss = tf.losses.CategoricalCrossentropy()
opt = tf.optimizers.Adam(learning_rate=0.001)
metric = tf.metrics.CategoricalAccuracy()
model.compile(loss=loss,optimizer=opt,metrics=[metric])

# %%
##Introducing the necessary functions to reduce the learning rate and stop fitting in time

from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau


earlystop = EarlyStopping(monitor='val_categorical_accuracy',
                             patience=5,
                             mode='auto',
                             verbose=1)

# reduce learning rate
reduce_lr = ReduceLROnPlateau(monitor='val_categorical_accuracy',
                             factor=0.3,
                             patience=5,
                             min_delta=0.001,
                             mode='auto',
                             verbose=1)

# %%
fitmodel = model.fit(train_data,epochs=80,validation_data=valid_data,verbose=2,callbacks=[earlystop, reduce_lr])
# Out:
# Epoch 1/80
# 760/760 - 50s - loss: 1.6063 - categorical_accuracy: 0.4531 - val_loss: 0.6836 - val_categorical_accuracy: 0.7587 - lr: 0.0010 - 50s/epoch - 66ms/step
# Epoch 2/80
# 760/760 - 47s - loss: 0.5472 - categorical_accuracy: 0.8102 - val_loss: 0.4098 - val_categorical_accuracy: 0.8571 - lr: 0.0010 - 47s/epoch - 62ms/step
# Epoch 3/80
# 760/760 - 47s - loss: 0.4029 - categorical_accuracy: 0.8650 - val_loss: 0.3656 - val_categorical_accuracy: 0.8791 - lr: 0.0010 - 47s/epoch - 62ms/step
# Epoch 4/80
# 760/760 - 47s - loss: 0.3155 - categorical_accuracy: 0.8972 - val_loss: 0.2763 - val_categorical_accuracy: 0.9099 - lr: 0.0010 - 47s/epoch - 62ms/step
# Epoch 5/80
# 760/760 - 47s - loss: 0.2777 - categorical_accuracy: 0.9110 - val_loss: 0.2452 - val_categorical_accuracy: 0.9204 - lr: 0.0010 - 47s/epoch - 62ms/step
# Epoch 6/80
# 760/760 - 48s - loss: 0.2635 - categorical_accuracy: 0.9162 - val_loss: 0.2613 - val_categorical_accuracy: 0.9171 - lr: 0.0010 - 48s/epoch - 63ms/step
# Epoch 7/80
# 760/760 - 48s - loss: 0.2474 - categorical_accuracy: 0.9208 - val_loss: 0.1980 - val_categorical_accuracy: 0.9373 - lr: 0.0010 - 48s/epoch - 63ms/step
# Epoch 8/80
# 760/760 - 47s - loss: 0.2242 - categorical_accuracy: 0.9288 - val_loss: 0.2391 - val_categorical_accuracy: 0.9301 - lr: 0.0010 - 47s/epoch - 62ms/step
# Epoch 9/80
# 760/760 - 48s - loss: 0.2129 - categorical_accuracy: 0.9347 - val_loss: 0.2511 - val_categorical_accuracy: 0.9253 - lr: 0.0010 - 48s/epoch - 63ms/step
# Epoch 10/80
# 760/760 - 47s - loss: 0.1987 - categorical_accuracy: 0.9385 - val_loss: 0.1999 - val_categorical_accuracy: 0.9410 - lr: 0.0010 - 47s/epoch - 62ms/step
# Epoch 11/80
# 760/760 - 46s - loss: 0.1995 - categorical_accuracy: 0.9387 - val_loss: 0.1981 - val_categorical_accuracy: 0.9418 - lr: 0.0010 - 46s/epoch - 60ms/step
# Epoch 12/80
# 760/760 - 48s - loss: 0.1964 - categorical_accuracy: 0.9414 - val_loss: 0.3063 - val_categorical_accuracy: 0.8954 - lr: 0.0010 - 48s/epoch - 63ms/step
# Epoch 13/80
# 760/760 - 48s - loss: 0.1918 - categorical_accuracy: 0.9414 - val_loss: 0.1902 - val_categorical_accuracy: 0.9418 - lr: 0.0010 - 48s/epoch - 63ms/step
# Epoch 14/80
# 760/760 - 47s - loss: 0.1821 - categorical_accuracy: 0.9458 - val_loss: 0.1626 - val_categorical_accuracy: 0.9492 - lr: 0.0010 - 47s/epoch - 62ms/step
# Epoch 15/80
# 760/760 - 46s - loss: 0.1791 - categorical_accuracy: 0.9458 - val_loss: 0.1839 - val_categorical_accuracy: 0.9400 - lr: 0.0010 - 46s/epoch - 61ms/step
# Epoch 16/80
# 760/760 - 47s - loss: 0.1734 - categorical_accuracy: 0.9497 - val_loss: 0.1674 - val_categorical_accuracy: 0.9521 - lr: 0.0010 - 47s/epoch - 62ms/step
# Epoch 17/80
# 760/760 - 47s - loss: 0.1710 - categorical_accuracy: 0.9488 - val_loss: 0.1494 - val_categorical_accuracy: 0.9523 - lr: 0.0010 - 47s/epoch - 62ms/step
# Epoch 18/80
# 760/760 - 50s - loss: 0.1577 - categorical_accuracy: 0.9523 - val_loss: 0.1530 - val_categorical_accuracy: 0.9561 - lr: 0.0010 - 50s/epoch - 66ms/step
# Epoch 19/80
# 760/760 - 47s - loss: 0.1682 - categorical_accuracy: 0.9504 - val_loss: 0.1848 - val_categorical_accuracy: 0.9434 - lr: 0.0010 - 47s/epoch - 62ms/step
# Epoch 20/80
# 760/760 - 47s - loss: 0.1603 - categorical_accuracy: 0.9515 - val_loss: 0.1794 - val_categorical_accuracy: 0.9441 - lr: 0.0010 - 47s/epoch - 62ms/step
# Epoch 21/80
# 760/760 - 47s - loss: 0.1578 - categorical_accuracy: 0.9544 - val_loss: 0.1560 - val_categorical_accuracy: 0.9539 - lr: 0.0010 - 47s/epoch - 62ms/step
# Epoch 22/80
# 760/760 - 49s - loss: 0.1566 - categorical_accuracy: 0.9536 - val_loss: 0.1928 - val_categorical_accuracy: 0.9419 - lr: 0.0010 - 49s/epoch - 65ms/step
# Epoch 23/80
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 760/760 - 47s - loss: 0.1603 - categorical_accuracy: 0.9538 - val_loss: 0.1740 - val_categorical_accuracy: 0.9446 - lr: 0.0010 - 47s/epoch - 62ms/step
# Epoch 23: early stopping

# %%
model.evaluate(test_data)
# Out:
# 152/152 [==============================] - 3s 15ms/step - loss: 0.1785 - categorical_accuracy: 0.9392
# [0.17854759097099304, 0.9392105340957642]

# %%
##See the necessary diagrams

plt.plot(fitmodel.history['categorical_accuracy'], label='accuracy')
plt.plot(fitmodel.history['val_categorical_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.55, 1])
plt.legend(loc='lower right')

test_loss, test_acc = model.evaluate(test_data, verbose=2)

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(fitmodel.history['categorical_accuracy'], label='Train Accuracy')
plt.plot(fitmodel.history['val_categorical_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(fitmodel.history['loss'], label='Train Loss')
plt.plot(fitmodel.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.ylim([0, max(max(fitmodel.history['loss']), max(fitmodel.history['val_loss']))])
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
test_loss, test_acc = model.evaluate(test_data, verbose=2)
print(f'\nTest accuracy: {test_acc}')
print(f'Test loss: {test_loss}')

epochs = range(len(fitmodel.history['categorical_accuracy']))

fig, ax1 = plt.subplots()

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy', color='tab:blue')
ax1.plot(epochs, fitmodel.history['categorical_accuracy'], label='Train Accuracy', color='tab:blue')
ax1.plot(epochs, fitmodel.history['val_categorical_accuracy'], label='Validation Accuracy', color='tab:cyan')
ax1.tick_params(axis='y', labelcolor='tab:blue')
ax1.set_ylim([0, 1])

ax2 = ax1.twinx()
ax2.set_ylabel('Loss', color='tab:red')
ax2.plot(epochs, fitmodel.history['loss'], label='Train Loss', color='tab:red')
ax2.plot(epochs, fitmodel.history['val_loss'], label='Validation Loss', color='tab:orange')
ax2.tick_params(axis='y', labelcolor='tab:red')
ax2.set_ylim([0, max(max(fitmodel.history['loss']), max(fitmodel.history['val_loss']))])

fig.legend(loc='upper right', bbox_to_anchor=(1, 1), bbox_transform=ax1.transAxes)

plt.title('Training and Validation Accuracy and Loss')
plt.show()
# Out:
# 152/152 - 3s - loss: 0.1785 - categorical_accuracy: 0.9392 - 3s/epoch - 18ms/step
# 152/152 - 2s - loss: 0.1785 - categorical_accuracy: 0.9392 - 2s/epoch - 16ms/step
#
# Test accuracy: 0.9392105340957642
# Test loss: 0.17854759097099304

# %%
y_p = model.predict(test_data)
# Out:
# 152/152 [==============================] - 2s 16ms/step

# %%
##Viewing photos of the dataset and testing the correctness of the network

def show_image_with_prediction(image, true_label, predicted_label, class_names):
    plt.imshow(image.astype(np.uint8))
    plt.title(f'True: {class_names[np.argmax(true_label)]}, Pred: {class_names[np.argmax(predicted_label)]}')
    plt.axis('off')
    plt.show()

def get_image_by_global_index(global_index, test_data, model, class_names):
    batch_size = 50  
    batch_number = global_index // batch_size
    local_index = global_index % batch_size

    # دریافت batch مربوطه
    for i in range(batch_number + 1):
        test_images, test_labels = next(test_data)
    
    y_p = model.predict(test_images)

    show_image_with_prediction(test_images[local_index], test_labels[local_index], y_p[local_index], class_name)

# %%
index = 6000
get_image_by_global_index(index, test_data, model, class_name)
# Out:
# 2/2 [==============================] - 0s 89ms/step
